# %% [markdown]
# # Working with Woodward-Fieser Rules

# %%
import sys, os
import numpy as np
import pandas as pd
from rdkit import Chem

sys.path.append('../src/')
import chromopredict as cp

# %%
nm, img = cp.predict(
    smiles='CC(=O)C=CC1=C(C)CCCC1(C)C',
    solvent='CCCCCCC',
    draw=False,
    debug=True,
    extended=False
)
# Out:
# Woodward-Calculation (mol-Type = woodward ):
# Base: 215
# Factor: 30
# Alpha: 0
# Beta: 0
# Gamma: 18
# Higher: 18
# Exo: 0
# Solvent: 0

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=500x500>

# %% [markdown]
# - cyan: base chromophore
# - green: additional double bond
# - dark blue: substituents (alkyl) in $\alpha$-, $\beta$ and $\beta$'-positions
